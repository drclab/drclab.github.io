# %% [markdown]
# # TS 201: Prophet Demo - Peyton Manning Page Views
#
# This notebook demonstrates how to use **Facebook Prophet** to forecast time series data, specifically looking at the daily Wikipedia page views for Peyton Manning. This accompanies the blog post **TS 201: Prophet**.
#
# ## 1. Setup and Data Loading
#
# First, we install and import the necessary libraries.

# %%
# !pip install pandas prophet matplotlib
# Out:
# Requirement already satisfied: pandas in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: prophet in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: matplotlib in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: numpy>=1.26.0 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from prophet) (1.3.0)
# Requirement already satisfied: holidays<1,>=0.25 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from prophet) (0.85)
# Requirement already satisfied: tqdm>=4.36.1 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: six>=1.5 in /home/cjduan/drclab.github.io/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Load the dataset
url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'
df = pd.read_csv(url)

# Prophet requires columns 'ds' (date) and 'y' (value)
df.head()
# Out:
# Importing plotly failed. Interactive plots will not work.
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %% [markdown]
# ## 2. Model Fitting
#
# We initialize the `Prophet` model and fit it to our data. Prophet automatically handles the daily seasonality and potential trend changes.

# %%
m = Prophet()
m.fit(df)
# Out:
# 11:09:10 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:11 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ## 3. Forecasting
#
# To forecast, we first create a dataframe with future dates. Here, we'll forecast 365 days into the future.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %% [markdown]
# Now we predict the future values. The `forecast` dataframe contains the predicted `yhat`, as well as the components and uncertainty intervals.

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.210119    7.496864    8.906282
# 3266 2017-01-16  8.535144    7.795778    9.283647
# 3267 2017-01-17  8.322571    7.609316    9.034911
# 3268 2017-01-18  8.155201    7.444263    8.905965
# 3269 2017-01-19  8.167158    7.430032    8.908585

# %% [markdown]
# ## 4. Visualization
#
# We can plot the forecast to see the trend and seasonality.

# %%
fig1 = m.plot(forecast)

# %% [markdown]
# We can also decompose the forecast into its components: Trend, Weekly Seasonality, and Yearly Seasonality.

# %%
fig2 = m.plot_components(forecast)

# %% [markdown]
# ## 5. Numerical Example: Super Bowl 50
#
# As discussed in the blog post, let's look at the specific forecast for **February 7, 2016** (Super Bowl 50).

# %%
target_date = '2016-02-07'
row = forecast[forecast['ds'] == target_date]

print(f"Forecast for {target_date}:")
print(f"Trend: {row['trend'].values[0]:.4f}")
print(f"Weekly: {row['weekly'].values[0]:.4f}")
print(f"Yearly: {row['yearly'].values[0]:.4f}")
print(f"yhat (Sum): {row['yhat'].values[0]:.4f}")
# Out:
# Forecast for 2016-02-07:
# Trend: 7.5426
# Weekly: 0.0483
# Yearly: 0.7397
# yhat (Sum): 8.3305
